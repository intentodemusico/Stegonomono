# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import os
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
print("TensorFlow version: {}".format(tf.__version__))
print("Eager execution: {}".format(tf.executing_eagerly()))
#Old dataset
#train_dataset_url = "https://raw.githubusercontent.com/intentodemusico/Stegonomono/master/ANN/Dataset/train_70000.csv"
#test_dataset_url = "https://raw.githubusercontent.com/intentodemusico/Stegonomono/master/ANN/Dataset/test_70000.csv"

#Old dataset
train_dataset_url = "https://raw.githubusercontent.com/intentodemusico/Stegonomono/master/ANN/NewDataset/Final/train_5000.csv"
test_dataset_url = "https://raw.githubusercontent.com/intentodemusico/Stegonomono/master/ANN/NewDataset/Final/test_5000.csv"
# Out:
# TensorFlow version: 2.0.0
# Eager execution: True

# %%
import pandas as pd

#%% Importing the dataset
labels=['Kurtosis', 'Skewness', 'Std', 'Range', 'Median', 'Geometric_Mean', 'Mobility', 'Complexity','IsStego','Location']
trainDataset = pd.read_csv(train_dataset_url,header=None,names=labels)
X_Train = trainDataset.iloc[:, :-2].values
Y_Train = trainDataset.iloc[:, -2].values

testDataset = pd.read_csv(test_dataset_url,header=None,names=labels)
X_Test = testDataset.iloc[:, :-2].values
Y_Test = testDataset.iloc[:, -2].values

# %%
#%% Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_Train = sc.fit_transform(X_Train)
X_Test = sc.transform(X_Test)

# %%
model = tf.keras.Sequential([
  tf.keras.layers.Dense(8, activation=tf.nn.relu, input_shape=(8,)),  # input shape required
  tf.keras.layers.Dense(4, activation=tf.nn.relu),
  tf.keras.layers.Dense(2, activation=tf.nn.relu),
  tf.keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

model.fit(X_Train, Y_Train, batch_size = 64, epochs = 250)
# Out:
# Train on 4000 samples
# Epoch 1/250
# 4000/4000 [==============================] - 1s 202us/sample - loss: 0.7035 - accuracy: 0.5560
# Epoch 2/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.6654 - accuracy: 0.6783
# Epoch 3/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.6005 - accuracy: 0.7487
# Epoch 4/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.5288 - accuracy: 0.7885
# Epoch 5/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.4759 - accuracy: 0.8363
# Epoch 6/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.4461 - accuracy: 0.8480
# Epoch 7/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.4259 - accuracy: 0.8555
# Epoch 8/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.4095 - accuracy: 0.8615
# Epoch 9/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.3945 - accuracy: 0.8677
# Epoch 10/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.3814 - accuracy: 0.8795
# Epoch 11/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.3703 - accuracy: 0.8823
# Epoch 12/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.3610 - accuracy: 0.8860
# Epoch 13/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.3518 - accuracy: 0.8905
# Epoch 14/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.3434 - accuracy: 0.8917
# Epoch 15/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.3270 - accuracy: 0.8942
# Epoch 16/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.2873 - accuracy: 0.8940
# Epoch 17/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.2625 - accuracy: 0.8938
# Epoch 18/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.2480 - accuracy: 0.8945
# Epoch 19/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.2365 - accuracy: 0.8995
# Epoch 20/250
# 4000/4000 [==============================] - 0s 26us/sample - loss: 0.2291 - accuracy: 0.9013
# Epoch 21/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.2235 - accuracy: 0.8988
# Epoch 22/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.2174 - accuracy: 0.9038
# Epoch 23/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.2134 - accuracy: 0.9047
# Epoch 24/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.2095 - accuracy: 0.9070
# Epoch 25/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.2065 - accuracy: 0.9057
# Epoch 26/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.2040 - accuracy: 0.9070
# Epoch 27/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.2018 - accuracy: 0.9090
# Epoch 28/250
# 4000/4000 [==============================] - 0s 29us/sample - loss: 0.1986 - accuracy: 0.9085
# Epoch 29/250
# 4000/4000 [==============================] - 0s 46us/sample - loss: 0.1970 - accuracy: 0.9090
# Epoch 30/250
# 4000/4000 [==============================] - 0s 43us/sample - loss: 0.1953 - accuracy: 0.9100
# Epoch 31/250
# 4000/4000 [==============================] - 0s 40us/sample - loss: 0.1924 - accuracy: 0.9128s - loss: 0.1924 - accuracy: 0.91
# Epoch 32/250
# 4000/4000 [==============================] - 0s 39us/sample - loss: 0.1918 - accuracy: 0.9120
# Epoch 33/250
# 4000/4000 [==============================] - 0s 40us/sample - loss: 0.1898 - accuracy: 0.9120
# Epoch 34/250
# 4000/4000 [==============================] - 0s 38us/sample - loss: 0.1881 - accuracy: 0.9128
# Epoch 35/250
# 4000/4000 [==============================] - 0s 39us/sample - loss: 0.1876 - accuracy: 0.9150
# Epoch 36/250
# 4000/4000 [==============================] - 0s 30us/sample - loss: 0.1859 - accuracy: 0.9150
# Epoch 37/250
# 4000/4000 [==============================] - 0s 30us/sample - loss: 0.1848 - accuracy: 0.9147
# Epoch 38/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1835 - accuracy: 0.9153
# Epoch 39/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.1835 - accuracy: 0.9162
# Epoch 40/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1814 - accuracy: 0.9172
# Epoch 41/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1802 - accuracy: 0.9193
# Epoch 42/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.1793 - accuracy: 0.9187
# Epoch 43/250
# 4000/4000 [==============================] - 0s 36us/sample - loss: 0.1782 - accuracy: 0.9187
# Epoch 44/250
# 4000/4000 [==============================] - 0s 34us/sample - loss: 0.1779 - accuracy: 0.9175
# Epoch 45/250
# 4000/4000 [==============================] - 0s 26us/sample - loss: 0.1768 - accuracy: 0.9193
# Epoch 46/250
# 4000/4000 [==============================] - 0s 26us/sample - loss: 0.1759 - accuracy: 0.9212
# Epoch 47/250
# 4000/4000 [==============================] - 0s 27us/sample - loss: 0.1745 - accuracy: 0.9215
# Epoch 48/250
# 4000/4000 [==============================] - 0s 32us/sample - loss: 0.1739 - accuracy: 0.9220
# Epoch 49/250
# 4000/4000 [==============================] - 0s 29us/sample - loss: 0.1728 - accuracy: 0.9215
# Epoch 50/250
# 4000/4000 [==============================] - 0s 32us/sample - loss: 0.1723 - accuracy: 0.9215
# Epoch 51/250
# 4000/4000 [==============================] - 0s 32us/sample - loss: 0.1720 - accuracy: 0.9212
# Epoch 52/250
# 4000/4000 [==============================] - 0s 33us/sample - loss: 0.1709 - accuracy: 0.9212
# Epoch 53/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.1693 - accuracy: 0.9227
# Epoch 54/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1689 - accuracy: 0.9220
# Epoch 55/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1679 - accuracy: 0.9225
# Epoch 56/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1672 - accuracy: 0.9212
# Epoch 57/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1681 - accuracy: 0.9225
# Epoch 58/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1664 - accuracy: 0.9235
# Epoch 59/250
# 4000/4000 [==============================] - 0s 29us/sample - loss: 0.1656 - accuracy: 0.9233
# Epoch 60/250
# 4000/4000 [==============================] - 0s 29us/sample - loss: 0.1644 - accuracy: 0.9240
# Epoch 61/250
# 4000/4000 [==============================] - 0s 27us/sample - loss: 0.1641 - accuracy: 0.9235
# Epoch 62/250
# 4000/4000 [==============================] - 0s 27us/sample - loss: 0.1627 - accuracy: 0.9245
# Epoch 63/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.1631 - accuracy: 0.9227
# Epoch 64/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1615 - accuracy: 0.9245
# Epoch 65/250
# 4000/4000 [==============================] - 0s 28us/sample - loss: 0.1614 - accuracy: 0.9247
# Epoch 66/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1606 - accuracy: 0.9237
# Epoch 67/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1614 - accuracy: 0.9240
# Epoch 68/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1596 - accuracy: 0.9252
# Epoch 69/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1593 - accuracy: 0.9240
# Epoch 70/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.1590 - accuracy: 0.9260
# Epoch 71/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1580 - accuracy: 0.9258
# Epoch 72/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1583 - accuracy: 0.9270
# Epoch 73/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.1574 - accuracy: 0.9252
# Epoch 74/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1574 - accuracy: 0.9243
# Epoch 75/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1566 - accuracy: 0.9265
# Epoch 76/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1562 - accuracy: 0.9262
# Epoch 77/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1561 - accuracy: 0.9265
# Epoch 78/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1552 - accuracy: 0.9258
# Epoch 79/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1554 - accuracy: 0.9255
# Epoch 80/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1554 - accuracy: 0.9260
# Epoch 81/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1547 - accuracy: 0.9247
# Epoch 82/250
# 4000/4000 [==============================] - 0s 26us/sample - loss: 0.1535 - accuracy: 0.9260
# Epoch 83/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1538 - accuracy: 0.9237
# Epoch 84/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1529 - accuracy: 0.9247
# Epoch 85/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1540 - accuracy: 0.9247
# Epoch 86/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.1529 - accuracy: 0.9243
# Epoch 87/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1527 - accuracy: 0.9250
# Epoch 88/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1517 - accuracy: 0.9233s - loss: 0.1502 - accuracy: 0.92
# Epoch 89/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1522 - accuracy: 0.9250
# Epoch 90/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.1517 - accuracy: 0.9255
# Epoch 91/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1508 - accuracy: 0.9255
# Epoch 92/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1507 - accuracy: 0.9260
# Epoch 93/250
# 4000/4000 [==============================] - 0s 19us/sample - loss: 0.1509 - accuracy: 0.9243
# Epoch 94/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1504 - accuracy: 0.9283
# Epoch 95/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.1505 - accuracy: 0.9235
# Epoch 96/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1504 - accuracy: 0.9243
# Epoch 97/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1492 - accuracy: 0.9247
# Epoch 98/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1487 - accuracy: 0.9255
# Epoch 99/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.1495 - accuracy: 0.9230
# Epoch 100/250
# 4000/4000 [==============================] - 0s 19us/sample - loss: 0.1497 - accuracy: 0.9255
# Epoch 101/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1486 - accuracy: 0.9247
# Epoch 102/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1479 - accuracy: 0.9265
# Epoch 103/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1474 - accuracy: 0.9260
# Epoch 104/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1486 - accuracy: 0.9255
# Epoch 105/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.1477 - accuracy: 0.9240
# Epoch 106/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1480 - accuracy: 0.9252
# Epoch 107/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1466 - accuracy: 0.9252
# Epoch 108/250
# 4000/4000 [==============================] - 0s 19us/sample - loss: 0.1481 - accuracy: 0.9255
# Epoch 109/250
# 4000/4000 [==============================] - 0s 19us/sample - loss: 0.1470 - accuracy: 0.9275
# Epoch 110/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1464 - accuracy: 0.9275
# Epoch 111/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.1467 - accuracy: 0.9265
# Epoch 112/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1465 - accuracy: 0.9258
# Epoch 113/250
# 4000/4000 [==============================] - 0s 19us/sample - loss: 0.1461 - accuracy: 0.9287
# Epoch 114/250
# 4000/4000 [==============================] - 0s 19us/sample - loss: 0.1455 - accuracy: 0.9273
# Epoch 115/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.1460 - accuracy: 0.9268
# Epoch 116/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1464 - accuracy: 0.9262
# Epoch 117/250
# 4000/4000 [==============================] - 0s 26us/sample - loss: 0.1450 - accuracy: 0.9275
# Epoch 118/250
# 4000/4000 [==============================] - 0s 26us/sample - loss: 0.1456 - accuracy: 0.9277
# Epoch 119/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.1453 - accuracy: 0.9285
# Epoch 120/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1443 - accuracy: 0.9275
# Epoch 121/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1460 - accuracy: 0.9273
# Epoch 122/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.1448 - accuracy: 0.9287
# Epoch 123/250
# 4000/4000 [==============================] - 0s 19us/sample - loss: 0.1443 - accuracy: 0.9273
# Epoch 124/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1440 - accuracy: 0.9290
# Epoch 125/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1437 - accuracy: 0.9287
# Epoch 126/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1452 - accuracy: 0.9287
# Epoch 127/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1434 - accuracy: 0.9277
# Epoch 128/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.1426 - accuracy: 0.9298
# Epoch 129/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1429 - accuracy: 0.9290
# Epoch 130/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1438 - accuracy: 0.9287
# Epoch 131/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.1431 - accuracy: 0.9293
# Epoch 132/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1426 - accuracy: 0.9285
# Epoch 133/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.1422 - accuracy: 0.9285
# Epoch 134/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1427 - accuracy: 0.9302
# Epoch 135/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1425 - accuracy: 0.9298
# Epoch 136/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1424 - accuracy: 0.9277
# Epoch 137/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1422 - accuracy: 0.9308
# Epoch 138/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1420 - accuracy: 0.9290
# Epoch 139/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.1418 - accuracy: 0.9293
# Epoch 140/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1416 - accuracy: 0.9277
# Epoch 141/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1418 - accuracy: 0.9287
# Epoch 142/250
# 4000/4000 [==============================] - 0s 27us/sample - loss: 0.1427 - accuracy: 0.9285
# Epoch 143/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1411 - accuracy: 0.9293
# Epoch 144/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1417 - accuracy: 0.9298
# Epoch 145/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.1418 - accuracy: 0.9302
# Epoch 146/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1416 - accuracy: 0.9270
# Epoch 147/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.1414 - accuracy: 0.9285
# Epoch 148/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1410 - accuracy: 0.9287
# Epoch 149/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1405 - accuracy: 0.9305
# Epoch 150/250
# 4000/4000 [==============================] - 0s 36us/sample - loss: 0.1410 - accuracy: 0.9285
# Epoch 151/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.1405 - accuracy: 0.9298
# Epoch 152/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1412 - accuracy: 0.9290
# Epoch 153/250
# 4000/4000 [==============================] - ETA: 0s - loss: 0.1487 - accuracy: 0.92 - 0s 24us/sample - loss: 0.1404 - accuracy: 0.9283
# Epoch 154/250
# 4000/4000 [==============================] - 0s 26us/sample - loss: 0.1406 - accuracy: 0.9293
# Epoch 155/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.1408 - accuracy: 0.9287
# Epoch 156/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1398 - accuracy: 0.9293
# Epoch 157/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.1399 - accuracy: 0.9298
# Epoch 158/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1403 - accuracy: 0.9275
# Epoch 159/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1400 - accuracy: 0.9295
# Epoch 160/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1399 - accuracy: 0.9287
# Epoch 161/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1395 - accuracy: 0.9305
# Epoch 162/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1400 - accuracy: 0.9298
# Epoch 163/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1396 - accuracy: 0.9283
# Epoch 164/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1397 - accuracy: 0.9277
# Epoch 165/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1390 - accuracy: 0.9295
# Epoch 166/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1407 - accuracy: 0.9273
# Epoch 167/250
# 4000/4000 [==============================] - 0s 19us/sample - loss: 0.1392 - accuracy: 0.9298
# Epoch 168/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1392 - accuracy: 0.9293
# Epoch 169/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1395 - accuracy: 0.9305
# Epoch 170/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.1383 - accuracy: 0.9285
# Epoch 171/250
# 4000/4000 [==============================] - 0s 26us/sample - loss: 0.1386 - accuracy: 0.9298
# Epoch 172/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1387 - accuracy: 0.9290
# Epoch 173/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.1392 - accuracy: 0.9305
# Epoch 174/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1395 - accuracy: 0.9293
# Epoch 175/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1394 - accuracy: 0.9277
# Epoch 176/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1385 - accuracy: 0.9305
# Epoch 177/250
# 4000/4000 [==============================] - 0s 19us/sample - loss: 0.1380 - accuracy: 0.9285
# Epoch 178/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1390 - accuracy: 0.9285
# Epoch 179/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1393 - accuracy: 0.9305
# Epoch 180/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1389 - accuracy: 0.9285
# Epoch 181/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1372 - accuracy: 0.9310
# Epoch 182/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1384 - accuracy: 0.9287
# Epoch 183/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1376 - accuracy: 0.9310
# Epoch 184/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1378 - accuracy: 0.9290
# Epoch 185/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1381 - accuracy: 0.9280
# Epoch 186/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1381 - accuracy: 0.9305
# Epoch 187/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1381 - accuracy: 0.9293
# Epoch 188/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1378 - accuracy: 0.9298
# Epoch 189/250
# 4000/4000 [==============================] - 0s 19us/sample - loss: 0.1382 - accuracy: 0.9302
# Epoch 190/250
# 4000/4000 [==============================] - 0s 19us/sample - loss: 0.1376 - accuracy: 0.9290
# Epoch 191/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1369 - accuracy: 0.9298
# Epoch 192/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1376 - accuracy: 0.9308
# Epoch 193/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1383 - accuracy: 0.9293
# Epoch 194/250
# 4000/4000 [==============================] - ETA: 0s - loss: 0.1381 - accuracy: 0.92 - 0s 25us/sample - loss: 0.1379 - accuracy: 0.9290
# Epoch 195/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.1374 - accuracy: 0.9305
# Epoch 196/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1377 - accuracy: 0.9305
# Epoch 197/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.1368 - accuracy: 0.9312
# Epoch 198/250
# 4000/4000 [==============================] - 0s 26us/sample - loss: 0.1363 - accuracy: 0.9300
# Epoch 199/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1374 - accuracy: 0.9287
# Epoch 200/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1380 - accuracy: 0.9302
# Epoch 201/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1366 - accuracy: 0.9290
# Epoch 202/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.1375 - accuracy: 0.9295
# Epoch 203/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1370 - accuracy: 0.9300
# Epoch 204/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1367 - accuracy: 0.9302
# Epoch 205/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1369 - accuracy: 0.9315
# Epoch 206/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1381 - accuracy: 0.9287
# Epoch 207/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1372 - accuracy: 0.9305
# Epoch 208/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1364 - accuracy: 0.9305
# Epoch 209/250
# 4000/4000 [==============================] - 0s 26us/sample - loss: 0.1361 - accuracy: 0.9305
# Epoch 210/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1371 - accuracy: 0.9298
# Epoch 211/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1374 - accuracy: 0.9315
# Epoch 212/250
# 4000/4000 [==============================] - 0s 22us/sample - loss: 0.1370 - accuracy: 0.9285
# Epoch 213/250
# 4000/4000 [==============================] - 0s 19us/sample - loss: 0.1366 - accuracy: 0.9308
# Epoch 214/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1376 - accuracy: 0.9287
# Epoch 215/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1362 - accuracy: 0.9290
# Epoch 216/250
# 4000/4000 [==============================] - 0s 19us/sample - loss: 0.1362 - accuracy: 0.9300
# Epoch 217/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.1363 - accuracy: 0.9300
# Epoch 218/250
# 4000/4000 [==============================] - 0s 27us/sample - loss: 0.1358 - accuracy: 0.9305
# Epoch 219/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.1357 - accuracy: 0.9308
# Epoch 220/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.1354 - accuracy: 0.9302
# Epoch 221/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.1368 - accuracy: 0.9298
# Epoch 222/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1351 - accuracy: 0.9310
# Epoch 223/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1357 - accuracy: 0.9305
# Epoch 224/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1367 - accuracy: 0.9293
# Epoch 225/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1355 - accuracy: 0.9298
# Epoch 226/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1357 - accuracy: 0.9315
# Epoch 227/250
# 4000/4000 [==============================] - 0s 26us/sample - loss: 0.1359 - accuracy: 0.9302
# Epoch 228/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1353 - accuracy: 0.9298
# Epoch 229/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.1355 - accuracy: 0.9308
# Epoch 230/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1357 - accuracy: 0.9302
# Epoch 231/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1360 - accuracy: 0.9305
# Epoch 232/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1352 - accuracy: 0.9317
# Epoch 233/250
# 4000/4000 [==============================] - 0s 25us/sample - loss: 0.1349 - accuracy: 0.9305
# Epoch 234/250
# 4000/4000 [==============================] - 0s 27us/sample - loss: 0.1362 - accuracy: 0.9302
# Epoch 235/250
# 4000/4000 [==============================] - 0s 26us/sample - loss: 0.1364 - accuracy: 0.9270
# Epoch 236/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.1360 - accuracy: 0.9308
# Epoch 237/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1358 - accuracy: 0.9293
# Epoch 238/250
# 4000/4000 [==============================] - 0s 24us/sample - loss: 0.1352 - accuracy: 0.9300
# Epoch 239/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1354 - accuracy: 0.9295
# Epoch 240/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1357 - accuracy: 0.9302
# Epoch 241/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1348 - accuracy: 0.9302
# Epoch 242/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1353 - accuracy: 0.9295
# Epoch 243/250
# 4000/4000 [==============================] - 0s 23us/sample - loss: 0.1352 - accuracy: 0.9305
# Epoch 244/250
# 4000/4000 [==============================] - 0s 19us/sample - loss: 0.1377 - accuracy: 0.9310
# Epoch 245/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1360 - accuracy: 0.9320
# Epoch 246/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1355 - accuracy: 0.9305
# Epoch 247/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1352 - accuracy: 0.9310
# Epoch 248/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1350 - accuracy: 0.9310
# Epoch 249/250
# 4000/4000 [==============================] - 0s 21us/sample - loss: 0.1340 - accuracy: 0.9308
# Epoch 250/250
# 4000/4000 [==============================] - 0s 20us/sample - loss: 0.1344 - accuracy: 0.9300

# %%
print(model)
model.evaluate(X_Train, Y_Train)
print(model.metrics_names)
#%% Predicting the Test set results
# Out:
# <tensorflow.python.keras.engine.sequential.Sequential object at 0x000001853A55AC88>
# 4000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# ['loss', 'accuracy']

# %%
from sklearn import metrics

# %%
y_pred = (model.predict(X_Test) > 0.5)
#%% Making the Confusion Matrix
cm = metrics.confusion_matrix(Y_Test, y_pred)
print("Confusion matrix\n",cm)

sensitivity = cm[0,0]/(cm[0,0]+cm[0,1])
print('Sensitivity :', sensitivity )

specificity = cm[1,1]/(cm[1,0]+cm[1,1])
print('Specificity :', specificity)
#%% 
print("Precision",metrics.precision_score(Y_Test, y_pred, average=None))
print("Accuracy",metrics.accuracy_score(Y_Test, y_pred))
print("F1",metrics.f1_score(Y_Test, y_pred, average=None))
# Out:
# Confusion matrix
#  [[468  32]
#  [ 46 454]]
# Sensitivity : 0.936
# Specificity : 0.908
# Precision [0.91050584 0.93415638]
# Accuracy 0.922
# F1 [0.92307692 0.92089249]

# %%
import numpy as np

# %%
fallas=np.array(labels,dtype='<U256')
y_pred=y_pred.reshape(len(y_pred))
print(np.shape(y_pred))
print(np.shape(Y_Test))
for i in range(len(y_pred)):
    if(y_pred[i]!=Y_Test[i]>0.5):
        fallas=np.vstack((fallas,testDataset.iloc[i].to_numpy()))

y_pred = (model.predict(X_Train) > 0.5).reshape(len(X_Train))
for i in range(len(y_pred)):
    if(y_pred[i]!=Y_Train[i]>0.5):
        fallas=np.vstack((fallas,trainDataset.iloc[i].to_numpy()))

asd="fallasEval.csv"
print("Fallas",len(fallas))
np.savetxt(asd,fallas,delimiter=",", fmt="%s")
# Out:
# (1000,)
# (1000,)
# Fallas 249

# %%
from keras.models import load_model

model.save('my_model.h5')  # creates a HDF5 file 'my_model.h5'
# Out:
# Using TensorFlow backend.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-de59ec22e657> in <module>
#       2 import sklearn.metrics as metrics
#       3 labels=['Kurtosis', 'Skewness', 'Std', 'Range', 'Median', 'Geometric_Mean', 'Mobility', 'Complexity']
# ----> 4 print("Precision",precision_score(Y_Test, y_pred, average=None))
#       5 print("Accuracy",accuracy_score(Y_Test, y_pred))
#       6 print("F1",f1_score(Y_Test, y_pred, average=None))
#
# NameError: name 'precision_score' is not defined
